# %%
import polars as pl
df = pl.read_csv("train.csv")
print(df.head())
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# ...

# %%
print(df.schema)
print(df.null_count())
print(df.describe())
# Out:
# Schema([('PassengerId', Int64), ('Survived', Int64), ('Pclass', Int64), ('Name', String), ('Sex', String), ('Age', Float64), ('SibSp', Int64), ('Parch', Int64), ('Ticket', String), ('Fare', Float64), ('Cabin', String), ('Embarked', String)])
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬──────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---  ┆ ---   ┆ ---      │
# │ u32         ┆ u32      ┆ u32    ┆ u32  ┆   ┆ u32    ┆ u32  ┆ u32   ┆ u32      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪══════╪═══════╪══════════╡
# │ 0           ┆ 0        ┆ 0      ┆ 0    ┆ … ┆ 0      ┆ 0    ┆ 687   ┆ 2        │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴──────┴───────┴──────────┘
# shape: (9, 13)
# ┌────────────┬─────────────┬──────────┬──────────┬───┬───────────┬───────────┬───────┬──────────┐
# ...

# %%
print(df["Pclass"].value_counts())
# Out:
# shape: (3, 2)
# ┌────────┬───────┐
# │ Pclass ┆ count │
# │ ---    ┆ ---   │
# │ i64    ┆ u32   │
# ╞════════╪═══════╡
# │ 2      ┆ 184   │
# │ 3      ┆ 491   │
# │ 1      ┆ 216   │
# └────────┴───────┘

# %%
print(
    df.filter(pl.col("Survived") == 1)
    .group_by("Sex")
    .agg(pl.count())
)
# Out:
# shape: (2, 2)
# ┌────────┬───────┐
# │ Sex    ┆ count │
# │ ---    ┆ ---   │
# │ str    ┆ u32   │
# ╞════════╪═══════╡
# │ male   ┆ 109   │
# │ female ┆ 233   │
# └────────┴───────┘
# <ipython-input-6-a8c7f54c0a16>:4: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
#   .agg(pl.count())

# %%
print(df.filter(pl.col("Age")>44))
# Out:
# shape: (115, 12)
# ┌─────────────┬──────────┬────────┬──────────────────┬───┬────────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name             ┆ … ┆ Ticket     ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---              ┆   ┆ ---        ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str              ┆   ┆ str        ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════════════════╪═══╪════════════╪═════════╪═══════╪══════════╡
# │ 7           ┆ 0        ┆ 1      ┆ McCarthy, Mr.    ┆ … ┆ 17463      ┆ 51.8625 ┆ E46   ┆ S        │
# │             ┆          ┆        ┆ Timothy J        ┆   ┆            ┆         ┆       ┆          │
# │ 12          ┆ 1        ┆ 1      ┆ Bonnell, Miss.   ┆ … ┆ 113783     ┆ 26.55   ┆ C103  ┆ S        │
# │             ┆          ┆        ┆ Elizabeth        ┆   ┆            ┆         ┆       ┆          │
# ...

# %%
import pandas as pd
import bottleneck as bn
df_pd = pd.read_csv("train.csv")

# %%
mean_age = bn.nanmean(df_pd["Age"].values)
std_age = bn.nanstd(df_pd["Age"].values)
print(f"Средний возраст: {mean_age}, Стандартное отклонение: {std_age}")
# Out:
# Средний возраст: 29.69911764705882, Стандартное отклонение: 14.516321150817317

# %%
df_pd["Fare_new"] = df_pd["Fare"] * 13

# %%
df_housing = pd.read_csv("Housing.csv")
def optimize_dtypes(df):
  for col in df.columns:
    if df[col].dtype == "int64":
      df[col] = pd.to_numeric(df[col], downcast="integer")
    elif df[col].dtype == "float64":
      df[col] = pd.to_numeric(df[col],downcast = "float")
    elif df[col].dtype == "object":
      if len(df[col].unique()) / len(df[col]) < 0.5:
        df[col] = df[col].astype("category")
  return df
print("До оптимизации:", df_housing.memory_usage(deep=True).sum())
df_optimized = optimize_dtypes(df_housing)
print("После оптимизации:", df_optimized.memory_usage(deep=True).sum())
# Out:
# До оптимизации: 257764
# После оптимизации: 11072
