# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
response = requests.get('https://lifehacker.ru/vkladki-v-telegram/')
response.text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU" data-capo=""><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Вышло большое обновление Telegram — с поддержкой HD-фото, обрезкой голосовых и вкладками — Лайфхакер</title>\n<link rel="preconnect" href="https://www.googletagmanager.com">\n<link rel="preconnect" href="https://top-fwz1.mail.ru">\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script>window.yaContextCb = window.yaContextCb || [];\nwindow.Ya || (window.Ya = {});\nwindow.Ya.adfoxCode || (window.Ya.adfoxCode = {});\nwindow.Ya.adfoxCode.hbCallbacks || (window.Ya.adfoxCode.hbCallbacks = []);</script>\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext.DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic.BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+ ...

# %%
base_url = 'https://lifehacker.ru/topics/technology/'
response = requests.get('https://lifehacker.ru/topics/technology/') # получаем контент первой страиниц
soup = BeautifulSoup(response.text, 'lxml') # инициализируем объект bs4 и задаем парсер lxml

# %%
soup.find_all('a', class_='lh-small-article-card__link') #
# Out:
# [<a aria-label="Вышло большое обновление Telegram — с поддержкой HD-фото, обрезкой голосовых и вкладками" class="lh-small-article-card__link" data-jest="link" href="/vkladki-v-telegram/" title="Вышло большое обновление Telegram — с поддержкой HD-фото, обрезкой голосовых и вкладками"><!--[--><!--]--></a>,
#  <a aria-label="На часах Samsung Galaxy Watch появилось автономное приложение «Яндекс Музыки»" class="lh-small-article-card__link" data-jest="link" href="/yandeks-muzyka-dlya-chasov/" title="На часах Samsung Galaxy Watch появилось автономное приложение «Яндекс Музыки»"><!--[--><!--]--></a>,
#  <a aria-label="Представлен Fi Series 3 Plus — собачий ИИ-ошейник с трекингом здоровья и привычек через Apple&amp;nbsp;Watch" class="lh-small-article-card__link" data-jest="link" href="/anons-fi-series-3-plus/" title="Представлен Fi Series 3 Plus — собачий ИИ-ошейник с трекингом здоровья и привычек через Apple&amp;nbsp;Watch"><!--[--><!--]--></a>,
#  <a aria-label="Как выбрать кондиционер для дома в 2025 году: всё, что нужно знать до покупки" class="lh-small-article-card__link" data-jest="link" href="/kak-vybrat-kondicioner/" title="Как выбрать кондиционер для дома в 2025 году: всё, что нужно знать до покупки"><!--[--><!--]--></a>,
#  <a aria-label="На маркетплейсах начали продавать Nintendo Switch 2 — по цене от 52 тысяч рублей" class="lh-small-article-card__link" data-jest="link" href="/na-marketpleisax-nachali-prodavat-nintendo-switch-2/" title="На маркетплейсах начали продавать Nintendo Switch 2 — по цене от 52 тысяч рублей"><!--[--><!--]--></a>,
#  <a aria-label="Объясняем за минуту: нужно ли закрывать окно при включённом кондиционере" class="lh-small-article-card__link" data-jest="link" href="/kondicioner-pri-otkrytom-okne/" title="Объясняем за минуту: нужно ли закрывать окно при включённом кондиционере"><!--[--><!--]--></a>,
#  <a aria-label="Samsung может отказаться от ИИ Google в пользу стартапа Perplexity" class="lh-small-article-card__link" data-jest="link" href="/perplexity-na-samsung/" title="Samsung может отказаться от ИИ Google в пользу стартапа Perplexity"><!--[--><!--]--></a>,
#  <a aria-label="Anker представила защищённую колонку Soundcore Boom 3i — она умеет самоочищаться и не&amp;nbsp;тонет" class="lh-small-article-card__link" data-jest="link" href="/anons-soundcore-boom-3i/" title="Anker представила защищённую колонку Soundcore Boom 3i — она умеет самоочищаться и не&amp;nbsp;тонет"><!--[--><!--]--></a>,
#  <a aria-label="Впервые бесплатно: ИИ-генератор видео Sora появился в приложении Microsoft Bing" class="lh-small-article-card__link" data-jest="link" href="/sora-bing/" title="Впервые бесплатно: ИИ-генератор видео Sora появился в приложении Microsoft Bing"><!--[--><!--]--></a>,
#  <a aria-label="Lenovo представила C55 — миниатюрную камеру&amp;nbsp;с 4K-видеозаписью и подсветкой вокруг объектива" class="lh-small-article-card__link" data-jest="link" href="/anons-lenovo-c55/" title="Lenovo представила C55 — миниатюрную камеру&amp;nbsp;с 4K-видеозаписью и подсветкой вокруг объектива"><!--[--><!--]--></a>,
#  <a aria-label="Представлен Realme C73 — тонкий бюджетный смартфон с батареей на&amp;nbsp;6 000 мА·ч" class="lh-small-article-card__link" data-jest="link" href="/anons-realme-c73/" title="Представлен Realme C73 — тонкий бюджетный смартфон с батареей на&amp;nbsp;6 000 мА·ч"><!--[--><!--]--></a>,
#  <a aria-label="9 новых приложений для Android: лучшее за&amp;nbsp;май" class="lh-small-article-card__link" data-jest="link" href="/prilozheniya-android-maj-2025/" title="9 новых приложений для Android: лучшее за&amp;nbsp;май"><!--[--><!--]--></a>,
#  <a aria-label="Сверхтонкий Galaxy S25 Edge проверили на прочность и попытались согнуть" class="lh-small-article-card__link" data-jest="link" href="/galaxy-s25-edge-prochnost/" title="Сверхтонкий Galaxy S25 Edge проверили на прочность и попытались согнуть"><!--[--><!--]--></a>,
#  <a aria-label="В «Блокноте» Windows 11 появилось форматирование текста — с курсивом, списками и гиперссылками" class="lh-small-article-card__link" data-jest="link" href="/formatirovanie-v-bloknote/" title="В «Блокноте» Windows 11 появилось форматирование текста — с курсивом, списками и гиперссылками"><!--[--><!--]--></a>,
#  <a aria-label="OpenAI собирается превратить ChatGPT в «суперпомощника» во всех аспектах жизни" class="lh-small-article-card__link" data-jest="link" href="/chatgpt-superpomoshhnik/" title="OpenAI собирается превратить ChatGPT в «суперпомощника» во всех аспектах жизни"><!--[--><!--]--></a>,
#  <a aria-label="Google выпустила приложение для запуска ИИ-моделей с Hugging Face прямо на смартфоне и без интернета" class="lh-small-article-card__link" data-jest="link" href="/anons-google-ai-edge-gallery/" title="Google выпустила приложение для запуска ИИ-моделей с Hugging Face прямо на смартфоне и без интернета"><!--[--><!--]--></a>,
#  <a aria-label="Как использовать смарт-колонку, если у вас ребёнок: 7 полезных сценариев" class="lh-small-article-card__link" data-jest="link" href="/scenarii-umnyx-kolonok-dlya-detei/" title="Как использовать смарт-колонку, если у вас ребёнок: 7 полезных сценариев"><!--[--><!--]--></a>,
#  <a aria-label="5 новых игр для Android и iOS: лучшее за&amp;nbsp;май" class="lh-small-article-card__link" data-jest="link" href="/igry-android-ios-mai-2025/" title="5 новых игр для Android и iOS: лучшее за&amp;nbsp;май"><!--[--><!--]--></a>,
#  <a aria-label="От компактных кранов до бойлеров для всей семьи: 10 лучших водонагревателей в 2025&amp;nbsp;году" class="lh-small-article-card__link" data-jest="link" href="/vodonagrevateli-2/" title="От компактных кранов до бойлеров для всей семьи: 10 лучших водонагревателей в 2025&amp;nbsp;году"><!--[--><!--]--></a>,
#  <a aria-label="В Греции пройдёт первая в истории международная Олимпиада среди роботов" class="lh-small-article-card__link" data-jest="link" href="/olimpiada-dlya-robotov/" title="В Греции пройдёт первая в истории международная Олимпиада среди роботов"><!--[--><!--]--></a>,
#  <a aria-label="9 новых приложений для iOS: лучшее за&amp;nbsp;май" class="lh-small-article-card__link" data-jest="link" href="/prilozhenij-ios-maj-2025/" title="9 новых приложений для iOS: лучшее за&amp;nbsp;май"><!--[--><!--]--></a>,
#  <a aria-label="Объясняем за минуту: может ли чат-бот иметь сознание и сводить вас с&amp;nbsp;ума" class="lh-small-article-card__link" data-jest="link" href="/chat-bot-svodit-s-uma/" title="Объясняем за минуту: может ли чат-бот иметь сознание и сводить вас с&amp;nbsp;ума"><!--[--><!--]--></a>,
#  <a aria-label="Обзор смарт-часов HUAWEI WATCH FIT 4 Pro и сравнение с WATCH FIT 4: эволюция и апгрейд" class="lh-small-article-card__link" data-jest="link" href="/huawei-watch-fit-4-pro-obzor/" title="Обзор смарт-часов HUAWEI WATCH FIT 4 Pro и сравнение с WATCH FIT 4: эволюция и апгрейд"><!--[--><!--]--></a>,
#  <a aria-label="Появились первые подробности о Xiaomi 16 — со Snapdragon 8 Elite 2 и 100-ваттной зарядкой" class="lh-small-article-card__link" data-jest="link" href="/utechka-xiaomi-16/" title="Появились первые подробности о Xiaomi 16 — со Snapdragon 8 Elite 2 и 100-ваттной зарядкой"><!--[--><!--]--></a>,
#  <a aria-label="Лучшие смартфоны мая" class="lh-small-article-card__link" data-jest="link" href="/smartfony-maya-2025/" title="Лучшие смартфоны мая"><!--[--><!--]--></a>,
#  <a aria-label="Какие гаджеты и аксессуары мы берём в отпуск: советует редакция Лайфхакера" class="lh-small-article-card__link" data-jest="link" href="/gadzhety-dlya-otpuska/" title="Какие гаджеты и аксессуары мы берём в отпуск: советует редакция Лайфхакера"><!--[--><!--]--></a>,
#  <a aria-label="Windows 11 сможет сама обновлять все приложения на ПК — даже сторонние" class="lh-small-article-card__link" data-jest="link" href="/obnovlenie-storonnix-prilozhenii-v-windows/" title="Windows 11 сможет сама обновлять все приложения на ПК — даже сторонние"><!--[--><!--]--></a>,
#  <a aria-label="Xiaomi выпустила ультратонкий пауэрбанк на 5 000 мА⋅ч с магнитным креплением" class="lh-small-article-card__link" data-jest="link" href="/anons-xiaomi-magnetic-ultra-slim/" title="Xiaomi выпустила ультратонкий пауэрбанк на 5 000 мА⋅ч с магнитным креплением"><!--[--><!--]--></a>,
#  <a aria-label="Представлен Tecno Pova Curve 5G: бюджетный и очень тонкий смартфон с батареей на 5 500 мА⋅ч" class="lh-small-article-card__link" data-jest="link" href="/anons-tecno-pova-curve/" title="Представлен Tecno Pova Curve 5G: бюджетный и очень тонкий смартфон с батареей на 5 500 мА⋅ч"><!--[--><!--]--></a>,
#  <a aria-label="Android 16 станет последним крупным обновлением для 18 устройств Samsung" class="lh-small-article-card__link" data-jest="link" href="/podderzhka-galaxy-s22/" title="Android 16 станет последним крупным обновлением для 18 устройств Samsung"><!--[--><!--]--></a>]

# %%
from types import CellType
raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')  # ищем все a-элементы с классом tm-article-comments-counter-link__link
links = [item.get('href').replace('/#comments', '') for item in raw_items] # получаем у ссылок только href-атрибут, убираем подстроку '/comments'
links
# Out:
# ['/vkladki-v-telegram',
#  '/yandeks-muzyka-dlya-chasov',
#  '/anons-fi-series-3-plus',
#  '/kak-vybrat-kondicioner',
#  '/na-marketpleisax-nachali-prodavat-nintendo-switch-2',
#  '/kondicioner-pri-otkrytom-okne',
#  '/perplexity-na-samsung',
#  '/anons-soundcore-boom-3i',
#  '/sora-bing',
#  '/anons-lenovo-c55',
#  '/anons-realme-c73',
#  '/prilozheniya-android-maj-2025',
#  '/galaxy-s25-edge-prochnost',
#  '/formatirovanie-v-bloknote',
#  '/chatgpt-superpomoshhnik',
#  '/anons-google-ai-edge-gallery',
#  '/scenarii-umnyx-kolonok-dlya-detei',
#  '/igry-android-ios-mai-2025',
#  '/vodonagrevateli-2',
#  '/olimpiada-dlya-robotov',
#  '/prilozhenij-ios-maj-2025',
#  '/chat-bot-svodit-s-uma',
#  '/huawei-watch-fit-4-pro-obzor',
#  '/utechka-xiaomi-16',
#  '/smartfony-maya-2025',
#  '/gadzhety-dlya-otpuska',
#  '/obnovlenie-storonnix-prilozhenii-v-windows',
#  '/anons-xiaomi-magnetic-ultra-slim',
#  '/anons-tecno-pova-curve',
#  '/podderzhka-galaxy-s22']

# %%
import requests
requests.get('https://lifehacker.ru/vkladki-v-telegram').text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU" data-capo=""><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Вышло большое обновление Telegram — с поддержкой HD-фото, обрезкой голосовых и вкладками — Лайфхакер</title>\n<link rel="preconnect" href="https://www.googletagmanager.com">\n<link rel="preconnect" href="https://top-fwz1.mail.ru">\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script>window.yaContextCb = window.yaContextCb || [];\nwindow.Ya || (window.Ya = {});\nwindow.Ya.adfoxCode || (window.Ya.adfoxCode = {});\nwindow.Ya.adfoxCode.hbCallbacks || (window.Ya.adfoxCode.hbCallbacks = []);</script>\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext.DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic.BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+ ...

# %%
parsed_urls = []

# %%
for page_num in range(1, 11):
    url = f'{base_url}/?page={page_num}' # подставляем нужный номер страницы для пагинации, дальше парсим каждую страницу аналогично коду выше
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')
    parsed_urls += [item.get('href').replace('/#comments', '') for item in raw_items]

# %%
len(parsed_urls)
# Out:
# 210

# %%
parsed_urls[35:45]
# Out:
# ['/kondicioner-pri-otkrytom-okne',
#  '/perplexity-na-samsung',
#  '/anons-soundcore-boom-3i',
#  '/sora-bing',
#  '/anons-lenovo-c55',
#  '/anons-realme-c73',
#  '/prilozheniya-android-maj-2025',
#  '/galaxy-s25-edge-prochnost',
#  '/formatirovanie-v-bloknote',
#  '/chatgpt-superpomoshhnik']

# %%
base_url = 'https://lifehacker.ru/'

# %%
response = requests.get('https://lifehacker.ru/vkladki-v-telegram/')
soup = BeautifulSoup(response.text, 'lxml')
soup.find('article', class_='single-article__post-content single-article__content-container').text
# Out:
# 'Команда Telegram представила июньское обновление. Оно включает возможность обрезать голосовые сообщения, темы в виде вкладок, поддержку отправки фотографий в улучшенном качестве и многое другое. Вот ключевые нововведения:Отправка сообщений каналамПользователи могут отправлять личные сообщения каналам и напрямую вести беседы с их владельцами. При этом конфиденциальность сохраняется: у авторов контента есть возможность скрывать свои контактные данные при общении с подпищиками. Они также могут установить плату за такие обращения, чтобы ограничить себя от спама и ненужных диалогов.Отображение тем в виде вкладокДля групп с темами теперь доступен обновлённый интерфейс с вкладками, который упрощает навигацию: вы можете мгновенно переходить к нужной теме из списка чатов и легко переключаться между беседами одним касанием. Есть два вида такой панели: большая сбоку и минималистичная в верхней части\xa0чата.Изображение: TelegramОбрезка голосовых сообщенийУ пользователей появилась возможность вырезать нужный фрагмент голосового сообщения перед отправкой. Для этого нужно просто указать метки начала и окончания. Кроме того, запись войсов и видеосообщений теперь можно приостанавливать и возобновлять.Отправка фотографий в улучшенном качествеС этого обновления при отправке фотографий доступен новый режим — «Отправить в высоком качестве». Он позволяет пересылать HD-изображения, которые содержат в четыре раза больше пикселей. При этом их загрузка занимает менее 0,5 Мб трафика, отметили разработчики.Изображение: TelegramОтправка медиафайлов в истории на\xa0iOSВладельцы iOS-устройств могут использовать стандартную кнопку «Поделиться», чтобы отправлять фотографии и видеозаписи из других приложений напрямую в редактор историй в Telegram. Больше не нужно переключаться между разными сервисами.Больше вариантов ответа в опросахОпросы в мессенджере теперь поддерживают до 12 вариантов ответа. Кроме того, у пользователей появилась возможность пересылать их в «Избранное», например, чтобы сохранить у себя результаты.Ноовсти технологий🚀На часах Samsung Galaxy Watch появилось автономное приложение «Яндекс Музыки»Представлен Fi Series 3 Plus — собачий ИИ-ошейник с трекингом здоровья и привычек через Apple WatchНа маркетплейсах начали продавать Nintendo Switch 2 — по цене от 52 тысяч рублей'

# %%
soup.find('h1', class_='article-card__title').text
# Out:
# 'Вышло большое обновление Telegram — с поддержкой HD-фото, обрезкой голосовых и вкладками'

# %%
result = []

for url in tqdm(parsed_urls):
    article = {}

    article_url = f'{base_url}{url}' # подставляем часть ссылки, ведущую материал
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'lxml')

    article['title'] = soup.find('h1', class_='article-card__title').text # Получаем текст из span в первом h1 с классом tm-title_h1
    article['text'] = soup.find('article', class_='single-article__post-content single-article__content-container').text # Получаем весь текст из div с классом tm-article-body
    votes_element = soup.find('span', class_='reactioncurrent-count')
    article['votes_count'] = votes_element.text.strip() if votes_element else 0


    result.append(article)
# Out:
# 100%|██████████| 210/210 [07:53<00:00,  2.25s/it]

# %%
pd.set_option('display.max_colwidth', 400)

# %%
data = pd.DataFrame(result)
data.head()
# Out:
#                                                                                                  title  \
# 0             Вышло большое обновление Telegram — с поддержкой HD-фото, обрезкой голосовых и вкладками
# 1                        На часах Samsung Galaxy Watch появилось автономное приложение «Яндекс Музыки»
# 2  Представлен Fi Series 3 Plus — собачий ИИ-ошейник с трекингом здоровья и привычек через Apple Watch
# 3                        Как выбрать кондиционер для дома в 2025 году: всё, что нужно знать до покупки
# 4                     На маркетплейсах начали продавать Nintendo Switch 2 — по цене от 52 тысяч рублей
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 0  Команда Telegram представила июньское обновление. Оно включает возможность обрезать голосовые сообщения, темы в виде вкладок, поддержку отправки фотографий в улучшенном качестве и многое другое. Вот ключевые нововведения:Отправка сообщений каналамПользователи могут отправлять личные сообщения каналам и напрямую вести беседы с их владельцами. При этом конфиденциальность сохраняется: у авторов к...
# 1  Стриминг «Яндекс Музыка» выпустил отдельное приложение для умных часов Samsung Galaxy Watch. Оно поддерживает все популярные функции сервиса.Благодаря eSim оно может работать без смартфона и полностью управляется с помощью умных часов, поэтому пользователям больше не обязательно брать телефон на пробежку или тренировку. Запускать «Мою волну», ставить лайки, добавлять треки, включать спортивные...
# 2  Компания Fi представила новую версию умного ошейника для собак — Series 3 Plus. Устройство использует ИИ для отслеживания активности питомца и поддерживает интеграцию с Apple Watch. Это позволяет владельцам наблюдать за поведением и здоровьем животного в реальном времени прямо с часов.Изображение: FiОшейник фиксирует шаги, сон, лай, облизывания, почёсывания, приёмы пищи и воды. Fi утверждает, ...
# 3  Определитесь с типом кондиционераПервое, что стоит учитывать при выборе кондиционера, — возможности установки в помещении. Как правило, для дома используется всего несколько типов кондиционеров.Настенные сплит-системыФото: Didecs / ShutterstockДля чего подходят: для квартир, коттеджей и практически любых жилых помещений.\nДостоинства: функция нагрева, минимум шума, качественная фильтрация возд...
# 4  На «Яндекс Маркете» и других маркетплейсах появились первые консоли Nintendo Switch 2 — за несколько дней до официального старта продаж, намеченного на 5 июня. Самое доступное предложение — бандл с игрой Mario Kart World — обойдётся примерно в 52 тысячи рублей. Однако в эту сумму не включена пошлина за доставку из-за рубежа, которая составляет примерно 6 тысяч рублей. Заказы по таким позициям,...
#
#    votes_count
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
